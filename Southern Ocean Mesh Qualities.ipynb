# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %run /home/douglasj/Development/lanl_work/tools/mpas_tools_repo/python_scripts/grid_quality/grid_quality.py -f ~/Development/mpi-scvt/southern_ocean/mesh.nc -b 100 -r 6371229.0
# Out:
# Average Cell Quality:  0.642550656724
# Minimum Cell Quality:  0.223588169091
#
# Average Triangle Quality:  0.877828799738
# Minimum Triangle Quality:  0.614863898253
#
# Average Angle Based Triangle Quality:  0.833078138544
# Minimum Angle Based Triangle Quality:  0.473919399788
#
# Number of obtuse triangles:  0  out of  508
